# %% [markdown]
# # Tratamiento de datos
# #### Se importa pandas y se lee el archivo de excel

# %%
import pandas as pd
dfCompras = pd.read_excel("Copia de Compras.xls")
dfCompras.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9083 entries, 0 to 9082
# Data columns (total 29 columns):
# Unnamed: 0                            9083 non-null int64
# Cod_Producto                          9083 non-null int64
# Id_Proveedor_Sucursal                 9083 non-null object
# Cod_Bodega                            9083 non-null int64
# Cod_Unidad_Negocio                    9083 non-null int64
# Cod_Centro_Operativo                  9083 non-null int64
# Cod_Centro_Costos                     9083 non-null int64
# Cod_Motivo_Compra                     1391 non-null object
# Cod_Tipo_Documento                    9083 non-null object
# Numero_Orden_Compra                   9083 non-null object
# Linea_Orden_Compra                    9083 non-null int64
# Fecha_Orden_Compra                    9083 non-null object
# Fecha_Entrega_Planeada                9083 non-null object
# Compra_Cantidad                       9083 non-null float64
# ...

# %% [markdown]
# ### Se elimina la columna "Cod_Motivo_Compra" por contener muchos valores nulos y se eliminan todos los registros que en todas las columnas sean nulos

# %%
dfCompras.drop(["Cod_Motivo_Compra"], axis = "columns", inplace = True)
dfCompras.dropna(how = "all", inplace = True)
dfCompras.head()
# Out:
#    Unnamed: 0  Cod_Producto Id_Proveedor_Sucursal  Cod_Bodega  \
# 0           0         10403               387|001          71
# 1           1         10403               387|001          71
# 2           2         10403               387|001          71
# 3           3         10318               387|001          71
# 4           4         10403               387|001          71
#
#    Cod_Unidad_Negocio  Cod_Centro_Operativo  Cod_Centro_Costos  \
# 0                   4                    11                  0
# 1                   4                    11                  0
# 2                   4                    11                  0
# 3                   4                    11                  0
# 4                   4                    11                  0
#
#   Cod_Tipo_Documento Numero_Orden_Compra  Linea_Orden_Compra  ...  \
# 0                OCM        11-OCM-17064              866902  ...
# 1                OCM        11-OCM-16175              813456  ...
# ...

# %% [markdown]
# ### Se divide en dos la columna "Id_Proveedor_Sucursal" y se elimina con "Compra_Moneda"

# %%
newData = dfCompras["Id_Proveedor_Sucursal"].str.split("|", n = 1, expand = True)
dfCompras.insert(2, column = "id_Proveedor", value = newData[0])
dfCompras.insert(3, column = "id_Sucursal", value = newData[1])
dfCompras.drop(["Id_Proveedor_Sucursal","Compra_Moneda"], axis = "columns", inplace = True)
dfCompras.head()
# Out:
#    Unnamed: 0  Cod_Producto id_Proveedor id_Sucursal  Cod_Bodega  \
# 0           0         10403          387         001          71
# 1           1         10403          387         001          71
# 2           2         10403          387         001          71
# 3           3         10318          387         001          71
# 4           4         10403          387         001          71
#
#    Cod_Unidad_Negocio  Cod_Centro_Operativo  Cod_Centro_Costos  \
# 0                   4                    11                  0
# 1                   4                    11                  0
# 2                   4                    11                  0
# 3                   4                    11                  0
# 4                   4                    11                  0
#
#   Cod_Tipo_Documento Numero_Orden_Compra  ...  Linea_Perfecta  \
# 0                OCM        11-OCM-17064  ...               0
# 1                OCM        11-OCM-16175  ...               0
# ...

# %%
dfCompras.Lead_Time_Primera_Entrega.quantile([0.25,0.5,0.75])
# Out:
# 0.25     5.0
# 0.50     8.0
# 0.75    14.0
# Name: Lead_Time_Primera_Entrega, dtype: float64

# %%
dfCompras.Lead_Time_Real_Max_Compra.quantile([0.25,0.5,0.75])
# Out:
# 0.25     6.0
# 0.50    10.0
# 0.75    19.0
# Name: Lead_Time_Real_Max_Compra, dtype: float64

# %%
dfCompras.Lead_Time_Real_Min_Compra.quantile([0.25,0.5,0.75])
# Out:
# 0.25     6.0
# 0.50     9.0
# 0.75    17.0
# Name: Lead_Time_Real_Min_Compra, dtype: float64

# %%
dfCompras.Lead_Time_Teorico_Compra.quantile([0.25,0.5,0.75])
# Out:
# 0.25     4.0
# 0.50     8.0
# 0.75    14.0
# Name: Lead_Time_Teorico_Compra, dtype: float64

# %%
dfCompras
# Out:
#       Unnamed: 0  Cod_Producto id_Proveedor id_Sucursal  Cod_Bodega  \
# 0              0         10403          387         001          71
# 1              1         10403          387         001          71
# 2              2         10403          387         001          71
# 3              3         10318          387         001          71
# 4              4         10403          387         001          71
# 5              5         10318          387         001          71
# 6              6         34862          373         001         221
# 7              7         34862          373         001         221
# 8              8         34863          373         001         305
# 9              9         34863          373         001         305
# 10            10         34862          373         001         305
# 11            11         34863          373         001         305
# 12            12         34864          373         001         305
# ...
